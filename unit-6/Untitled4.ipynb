# %%
import pandas as pd
from pandas.io.json import json_normalize
import json

# %%
nhl = pd.read_json('nhl.json')

# %%
nhl.head()
# Out:
#                                            copyright  \
# 0  NHL and the NHL Shield are registered trademar...
# 1  NHL and the NHL Shield are registered trademar...
# 2  NHL and the NHL Shield are registered trademar...
# 3  NHL and the NHL Shield are registered trademar...
# 4  NHL and the NHL Shield are registered trademar...
#
#                                                teams
# 0  {'id': 1, 'name': 'New Jersey Devils', 'link':...
# 1  {'id': 2, 'name': 'New York Islanders', 'link'...
# 2  {'id': 3, 'name': 'New York Rangers', 'link': ...
# 3  {'id': 4, 'name': 'Philadelphia Flyers', 'link...
# 4  {'id': 5, 'name': 'Pittsburgh Penguins', 'link...

# %%
teams = json_normalize(nhl ['teams'])

# %%
teams
# Out:
#    abbreviation  active  conference.id        conference.link conference.name  \
# 0           NJD    True              6  /api/v1/conferences/6         Eastern
# 1           NYI    True              6  /api/v1/conferences/6         Eastern
# 2           NYR    True              6  /api/v1/conferences/6         Eastern
# 3           PHI    True              6  /api/v1/conferences/6         Eastern
# 4           PIT    True              6  /api/v1/conferences/6         Eastern
# 5           BOS    True              6  /api/v1/conferences/6         Eastern
# 6           BUF    True              6  /api/v1/conferences/6         Eastern
# 7           MTL    True              6  /api/v1/conferences/6         Eastern
# 8           OTT    True              6  /api/v1/conferences/6         Eastern
# 9           TOR    True              6  /api/v1/conferences/6         Eastern
# 10          CAR    True              6  /api/v1/conferences/6         Eastern
# ...
