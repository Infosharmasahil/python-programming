# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

print(df)
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur     Grass  Poison   45      49       49
# 1      2                    Ivysaur     Grass  Poison   60      62       63
# 2      3                   Venusaur     Grass  Poison   80      82       83
# 3      3      VenusaurMega Venusaur     Grass  Poison   80     100      123
# 4      4                 Charmander      Fire     NaN   39      52       43
# 5      5                 Charmeleon      Fire     NaN   58      64       58
# 6      6                  Charizard      Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 9      7                   Squirtle     Water     NaN   44      48       65
# 10     8                  Wartortle     Water     NaN   59      63       80
# ...

# %%
#read headers

df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#read each column
df['Name']
# Out:
# 0                      Bulbasaur
# 1                        Ivysaur
# 2                       Venusaur
# 3          VenusaurMega Venusaur
# 4                     Charmander
# 5                     Charmeleon
# 6                      Charizard
# 7      CharizardMega Charizard X
# 8      CharizardMega Charizard Y
# 9                       Squirtle
# 10                     Wartortle
# 11                     Blastoise
# 12       BlastoiseMega Blastoise
# 13                      Caterpie
# 14                       Metapod
# 15                    Butterfree
# 16                        Weedle
# 17                        Kakuna
# 18                      Beedrill
# 19         BeedrillMega Beedrill
# 20                        Pidgey
# 21                     Pidgeotto
# 22                       Pidgeot
# 23           PidgeotMega Pidgeot
# 24                       Rattata
# 25                      Raticate
# 26                       Spearow
# 27                        Fearow
# ...

# %%
#read each colum

df[['Name','Type 1','HP']]
# Out:
#                           Name    Type 1   HP
# 0                    Bulbasaur     Grass   45
# 1                      Ivysaur     Grass   60
# 2                     Venusaur     Grass   80
# 3        VenusaurMega Venusaur     Grass   80
# 4                   Charmander      Fire   39
# 5                   Charmeleon      Fire   58
# 6                    Charizard      Fire   78
# 7    CharizardMega Charizard X      Fire   78
# 8    CharizardMega Charizard Y      Fire   78
# 9                     Squirtle     Water   44
# 10                   Wartortle     Water   59
# 11                   Blastoise     Water   79
# 12     BlastoiseMega Blastoise     Water   79
# 13                    Caterpie       Bug   45
# 14                     Metapod       Bug   50
# 15                  Butterfree       Bug   60
# 16                      Weedle       Bug   40
# 17                      Kakuna       Bug   45
# 18                    Beedrill       Bug   65
# ...

# %%
#another way to read column

df.Name[0:7]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# 5               Charmeleon
# 6                Charizard
# Name: Name, dtype: object

# %%
# read row

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#read specific row, use iloc-integar location

df.iloc[5]
# Out:
# #                      5
# Name          Charmeleon
# Type 1              Fire
# Type 2               NaN
# HP                    58
# Attack                64
# Defense               58
# Sp. Atk               80
# Sp. Def               65
# Speed                 80
# Generation             1
# Legendary          False
# Name: 5, dtype: object

# %%
#read specific location row & column

df.iloc[5,2]
# Out:
# 'Fire'

# %%
df.iloc[0:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.loc[df['Name'] == 'Charmeleon']
# Out:
#    #        Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 5  5  Charmeleon   Fire    NaN  58      64       58       80       65     80
#
#    Generation  Legendary
# 5           1      False

# %%
#Describe used for high-level mean, standard deviations, counts....
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
#sorting values alphabatical

df.sort_values('Name')[0:10]
# Out:
#        #                       Name   Type 1  Type 2  HP  Attack  Defense  \
# 510  460                  Abomasnow    Grass     Ice  90      92       75
# 511  460    AbomasnowMega Abomasnow    Grass     Ice  90     132      105
# 68    63                       Abra  Psychic     NaN  25      20       15
# 392  359                      Absol     Dark     NaN  65     130       60
# 393  359            AbsolMega Absol     Dark     NaN  65     150       60
# 678  617                   Accelgor      Bug     NaN  80      70       40
# 750  681       AegislashBlade Forme    Steel   Ghost  60     150       50
# 751  681      AegislashShield Forme    Steel   Ghost  60      50      150
# 153  142                 Aerodactyl     Rock  Flying  80     105       65
# 154  142  AerodactylMega Aerodactyl     Rock  Flying  80     135       85
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       92       85     60           4      False
# ...

# %%
#descending order

df.sort_values('Name', ascending =False)[0:10]
# Out:
#        #              Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 794  718  Zygarde50% Forme    Dragon    Ground  108     100      121       81
# 695  634          Zweilous      Dark    Dragon   72      85       70       65
# 46    41             Zubat    Poison    Flying   40      45       35       30
# 631  570             Zorua      Dark       NaN   40      65       40       80
# 632  571           Zoroark      Dark       NaN   60     105       60      120
# 286  263         Zigzagoon    Normal       NaN   38      30       41       30
# 707  644            Zekrom    Dragon  Electric  100     150      120      120
# 582  523         Zebstrika  Electric       NaN   75     100       63       80
# 157  145            Zapdos  Electric    Flying   90      90       85      125
# 367  335          Zangoose    Normal       NaN   73     115       60       60
#
#      Sp. Def  Speed  Generation  Legendary
# 794       95     95           6       True
# ...

# %%
df.sort_values(['Name', 'Type 1', 'HP'], ascending=False)[0:10]
# Out:
#        #              Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 794  718  Zygarde50% Forme    Dragon    Ground  108     100      121       81
# 695  634          Zweilous      Dark    Dragon   72      85       70       65
# 46    41             Zubat    Poison    Flying   40      45       35       30
# 631  570             Zorua      Dark       NaN   40      65       40       80
# 632  571           Zoroark      Dark       NaN   60     105       60      120
# 286  263         Zigzagoon    Normal       NaN   38      30       41       30
# 707  644            Zekrom    Dragon  Electric  100     150      120      120
# 582  523         Zebstrika  Electric       NaN   75     100       63       80
# 157  145            Zapdos  Electric    Flying   90      90       85      125
# 367  335          Zangoose    Normal       NaN   73     115       60       60
#
#      Sp. Def  Speed  Generation  Legendary
# 794       95     95           6       True
# ...

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
#dropping a column

df = df.drop(columns = ['Total'])

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df['Total_sum'] = df.iloc[:, 4:10].sum(axis=1) #added total column again

# %%
#moving a column

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total_sum  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison        318  45      49       49
# 1  2                Ivysaur  Grass  Poison        405  60      62       63
# 2  3               Venusaur  Grass  Poison        525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison        625  80     100      123
# 4  4             Charmander   Fire     NaN        309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.to_csv('Modified.csv')

# %%
df.loc[df['Type 1'] == 'Grass'] [0:10] #locating specific df
# Out:
#      #                   Name Type 1  Type 2  Total_sum  HP  Attack  Defense  \
# 0    1              Bulbasaur  Grass  Poison        318  45      49       49
# 1    2                Ivysaur  Grass  Poison        405  60      62       63
# 2    3               Venusaur  Grass  Poison        525  80      82       83
# 3    3  VenusaurMega Venusaur  Grass  Poison        625  80     100      123
# 48  43                 Oddish  Grass  Poison        320  45      50       55
# 49  44                  Gloom  Grass  Poison        395  60      65       70
# 50  45              Vileplume  Grass  Poison        490  75      80       85
# 75  69             Bellsprout  Grass  Poison        300  50      75       35
# 76  70             Weepinbell  Grass  Poison        390  65      90       50
# 77  71             Victreebel  Grass  Poison        490  80     105       65
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# ...

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['Total_sum'] > 300)]

# %%
new_df
# Out:
#        #                   Name Type 1  Type 2  Total_sum   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison        318   45      49
# 1      2                Ivysaur  Grass  Poison        405   60      62
# 2      3               Venusaur  Grass  Poison        525   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison        625   80     100
# 48    43                 Oddish  Grass  Poison        320   45      50
# 49    44                  Gloom  Grass  Poison        395   60      65
# 50    45              Vileplume  Grass  Poison        490   75      80
# 76    70             Weepinbell  Grass  Poison        390   65      90
# 77    71             Victreebel  Grass  Poison        490   80     105
# 344  315                Roselia  Grass  Poison        400   50      60
# 452  407               Roserade  Grass  Poison        515   60      70
# 652  591              Amoonguss  Grass  Poison        464  114      85
#
# ...

# %%
new_df.to_csv('Filter_testing_newFile')

# %%
new_df
# Out:
#        #                   Name Type 1  Type 2  Total_sum   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison        318   45      49
# 1      2                Ivysaur  Grass  Poison        405   60      62
# 2      3               Venusaur  Grass  Poison        525   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison        625   80     100
# 48    43                 Oddish  Grass  Poison        320   45      50
# 49    44                  Gloom  Grass  Poison        395   60      65
# 50    45              Vileplume  Grass  Poison        490   75      80
# 76    70             Weepinbell  Grass  Poison        390   65      90
# 77    71             Victreebel  Grass  Poison        490   80     105
# 344  315                Roselia  Grass  Poison        400   50      60
# 452  407               Roserade  Grass  Poison        515   60      70
# 652  591              Amoonguss  Grass  Poison        464  114      85
#
# ...

# %%
df.loc[df['Type 2'] == 'Poison', 'Type 2'] = 'Boom'

df
# Out:
#        #                       Name    Type 1  Type 2  Total_sum   HP  Attack  \
# 0      1                  Bulbasaur     Grass    Boom        318   45      49
# 1      2                    Ivysaur     Grass    Boom        405   60      62
# 2      3                   Venusaur     Grass    Boom        525   80      82
# 3      3      VenusaurMega Venusaur     Grass    Boom        625   80     100
# 4      4                 Charmander      Fire     NaN        309   39      52
# 5      5                 Charmeleon      Fire     NaN        405   58      64
# 6      6                  Charizard      Fire  Flying        534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon        634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying        634   78     104
# 9      7                   Squirtle     Water     NaN        314   44      48
# 10     8                  Wartortle     Water     NaN        405   59      63
# ...
