# %%
import chart_studio.plotly

# %%
# Import the libraries for data processing and Visualization

import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
from plotly.offline import iplot
import plotly.express as px
import plotly.graph_objects as go
import cufflinks as cf

import plotly.tools as tls
import chart_studio.plotly


# %matplotlib inline

# %%
banking_data = pd.read_csv('https://query.data.world/s/7zpxoie4b5jmbujxl4ltpsmw5xqxji')

banking_data.head()
# Out:
#   Date received                  Product                 Sub-product  \
# 0    07/29/2013  Bank account or service            Checking account
# 1    07/29/2013  Bank account or service            Checking account
# 2    07/29/2013  Bank account or service            Checking account
# 3    07/29/2013  Bank account or service            Checking account
# 4    07/29/2013  Bank account or service  Other bank product/service
#
#                                      Issue  Sub-issue  \
# 0                Using a debit or ATM card        NaN
# 1  Account opening, closing, or management        NaN
# 2                 Deposits and withdrawals        NaN
# 3                 Deposits and withdrawals        NaN
# 4                 Deposits and withdrawals        NaN
#
#   Consumer complaint narrative Company public response                Company  \
# 0                          NaN                     NaN  Wells Fargo & Company
# ...

# %%
for ind, column in banking_data.itercolumns()
# Out:
#   File "<ipython-input-6-efa7280a165a>", line 1
#     for ind, column in banking_data.itercolumns()
#                                                  ^
# SyntaxError: invalid syntax

# %%
for ind, row in banking_data.iterrows():
    banking_data[ind,'Diff_Date'] = row['Date received'] - row['Date sent to company'] 
    banking_data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ddf9908f8950> in <module>
#       1 for ind, row in banking_data.iterrows():
# ----> 2     banking_data[ind,'Diff_Date'] = row['Date received'] - row['Date sent to company']
#       3     banking_data.head()
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
